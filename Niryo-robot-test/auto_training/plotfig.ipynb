# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
win = np.arange(5,16,1)
regloss1 = np.array([0.29903557896614075,
                     0.27956005930900574,
                     0.2892515957355499,
                     0.24259606003761292,
                     0.20356178283691406,
                     0.19353213906288147,
                     0.1721351593732834,
                     0.15462245047092438,
                     0.17945092916488647,
                     0.20555202662944794,
                     0.16871502995491028])
regloss2 = np.array([0.3086400330066681,
                     0.26164793968200684,
                     0.24522297084331512,
                     0.2526622712612152,
                     0.2173382192850113,
                     0.21899807453155518,
                     0.17781761288642883,
                     0.1970437467098236,
                     0.20391203463077545,
                     0.18004398047924042,
                     0.2106197476387024])

fig = plt.figure(dpi=150)
ax = fig.add_subplot(111)

ax.plot(win, regloss1, "--o", label="random seed = 42")
ax.plot(win, regloss2, "--o", label="random seed = 43")

ax.legend(fontsize=12)
ax.grid()
ax.set_title("Best MSE VS. Window Length", fontsize=15)
ax.set_xlabel("Window Length", fontsize=14)
ax.set_ylabel("Best MSE ($mm^2$)", fontsize=14)

ax.set_xticks(range(5, 16, 2))
ax.tick_params(axis='both', labelsize=13)

fig.tight_layout()
plt.savefig("both_trend.pdf", format="pdf", bbox_inches="tight")
plt.show()
